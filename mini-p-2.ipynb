# %%
print("TOTAL CHOCOLATES ARE:327")
print("TOTAL STUDENTS:78")
choc=327
students=78
print("Remaining chocolates with the teacher after equally distributing 327 chocolates to 78 students is:",choc % students)
# Out:
# TOTAL CHOCOLATES ARE:327
# TOTAL STUDENTS:78
# Remaining chocolates with the teacher after equally distributing 327 chocolates to 78 students is: 15

# %%
print("Welcome come to the registration of Domino's 25th anniversary...!")
print("kindly enroll your details to win a suprise gift!")
name=str(input("Name:"))
number=int(input("Mobile Number:"))
age=int(input("Age:"))
email=input("Email Id:")
print("Hi",name,"!! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.",'\n',"Once the lucky draw results are announced you will receive a message on your mobile number:",number,"An detailed description of your gift on your email Id :",email,'\n',"Thank you for being a valued customer",name,"!!!""Dominos"
)
# Out:
# Welcome come to the registration of Domino's 25th anniversary...!
# kindly enroll your details to win a suprise gift!
# Name:jabir
# Mobile Number:123
# Age:23
# Email Id:jksdn@gmail.com
# Hi jabir !! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.
#  Once the lucky draw results are announced you will receive a message on your mobile number: 123 An detailed description of your gift on your email Id : jksdn@gmail.com
#  Thank you for being a valued customer jabir !!!Dominos

# %%
print("TOTAL NUMBER OF STUDENTS:60")
print("NUMBER OF STUDENTS PER TEAM:4")
totalStudents=60
perTeam=4
print("possible teams:",totalStudents/perTeam)
# Out:
# TOTAL NUMBER OF STUDENTS:60
# NUMBER OF STUDENTS PER TEAM:4
# possible teams: 15.0

# %%
print("FAHRENHEIT TO CELSIUS")
f=int(input("Type the fahrenheit:"))
c=(f-32)*5/9
print("Celsius is:",c)
# Out:
# FAHRENHEIT TO CELSIUS
# Type the fahrenheit:1
# Celsius is: -17.22222222222222
