# %%
petName=str(input("enter the pet name:"))
rev=petName[::-1]
if petName==rev:
  print("It is palindrome")
else:
  print("It is not palindrome")
# Out:
# enter the pet name:puppy
# It is not palindrome
