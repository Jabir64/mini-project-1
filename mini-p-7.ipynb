# %%
def Branch_reports(branch_name,total_stock, sold_stock):
  available_stock = total_stock - sold_stock

  print("Branch :",branch_name)
  print("Available Stocks:",available_stock)
  print("Sold Stocks:",sold_stock)

  def chennai():

    Branch_reports("chennai")

  def bengalure():

     Branch_reports("bengalure")

  def kerala():

     Branch_reports("kerala")


Branch_reports("kerala",1000,50)
# Out:
# Branch : kerala
# Available Stocks: 950
# Sold Stocks: 50
