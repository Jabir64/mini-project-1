# %%
def quiz():
  score = 0
  q1=int(input("subtract of 10- 10:"))
  ans1=0
  if q1==ans1:
    print("Correct answer")
    score += 1
    print("current score",score)
  else:
    print("wrong")

  q2=int(input("how many alphabets in english:"))
  ans2=26
  if q2==ans2:
    print("Correct answer")
    score += 1
    print("current score:",score)
  else:
    print("wrong")

  q3=input("what is h2o")
  ans3="water"
  if q3==ans3:
      print("Correct answer")
      score += 1
      print("current score",score)
  else:
      print("wrong")
quiz()
# Out:
# subtract of 10- 10:0
# Correct answer
# current score 1
# how many alphabets in english:26
# Correct answer
# current score: 2
# what is h2owater
# Correct answer
# current score 3
